# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 644

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build query URL
url="http://api.openweathermap.org/data/2.5/weather?"
# city=""
query_url=url+"appid="+api_key+"&units=imperial"+"&q=" #+city

# %% [markdown]
# ## Use openweather api to extract data

# %%
#create row counter
counter=0
set_num=1
clouds = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []
city_list=[]
print("Beginning Data Retrieval")
print("-"*30)
# Iterrows: loop cities in query_url
for city in cities:
    try:
        response=requests.get(query_url+city).json()
        clouds.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        #update record number and set number
        if counter>=49:
            counter=1
            set_num+=1
            city_list.append(city)
        else:
            counter+=1
            city_list.append(city)
        print(f"Processing Record {counter} of Set {set_num} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("-"*30)
print("Data Retrieval Complete")
print("-"*30)
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | te anau
# Processing Record 2 of Set 1 | pangoa
# Processing Record 3 of Set 1 | galt
# Processing Record 4 of Set 1 | anadyr
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | tiksi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | honiara
# City not found. Skipping...
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | hamilton
# Processing Record 13 of Set 1 | barrow
# City not found. Skipping...
# Processing Record 14 of Set 1 | nishihara
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | sept-iles
# City not found. Skipping...
# Processing Record 17 of Set 1 | tabas
# Processing Record 18 of Set 1 | galle
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | khatanga
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | adamantina
# City not found. Skipping...
# Processing Record 24 of Set 1 | neftcala
# Processing Record 25 of Set 1 | saint-joseph
# Processing Record 26 of Set 1 | magadan
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | jiuquan
# Processing Record 29 of Set 1 | saint-augustin
# Processing Record 30 of Set 1 | puerto narino
# Processing Record 31 of Set 1 | bubaque
# Processing Record 32 of Set 1 | dunedin
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | dikson
# Processing Record 36 of Set 1 | itoman
# City not found. Skipping...
# Processing Record 37 of Set 1 | wahiawa
# Processing Record 38 of Set 1 | dicabisagan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of Set 1 | egvekinot
# City not found. Skipping...
# Processing Record 40 of Set 1 | blind river
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | senekal
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | castro
# Processing Record 46 of Set 1 | norman wells
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | meulaboh
# Processing Record 49 of Set 1 | oneonta
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | hambantota
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | aklavik
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | adolfo lopez mateos
# Processing Record 8 of Set 2 | puquio
# Processing Record 9 of Set 2 | malayal
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | arraial do cabo
# Processing Record 12 of Set 2 | bozoum
# Processing Record 13 of Set 2 | bemidji
# Processing Record 14 of Set 2 | san patricio
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | tasiilaq
# Processing Record 17 of Set 2 | port elizabeth
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | codrington
# Processing Record 20 of Set 2 | maua
# Processing Record 21 of Set 2 | busselton
# Processing Record 22 of Set 2 | malaya serdoba
# Processing Record 23 of Set 2 | coquimbo
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 2 | la grande
# Processing Record 25 of Set 2 | chumikan
# Processing Record 26 of Set 2 | verkhnevilyuysk
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | caninde de sao francisco
# Processing Record 29 of Set 2 | paraiba do sul
# Processing Record 30 of Set 2 | chuy
# Processing Record 31 of Set 2 | inirida
# Processing Record 32 of Set 2 | pacific grove
# Processing Record 33 of Set 2 | nanortalik
# Processing Record 34 of Set 2 | hilo
# City not found. Skipping...
# Processing Record 35 of Set 2 | iqaluit
# Processing Record 36 of Set 2 | alofi
# Processing Record 37 of Set 2 | mankono
# Processing Record 38 of Set 2 | vostok
# Processing Record 39 of Set 2 | broken hill
# Processing Record 40 of Set 2 | richards bay
# Processing Record 41 of Set 2 | batagay-alyta
# Processing Record 42 of Set 2 | charters towers
# Processing Record 43 of Set 2 | cherskiy
# Processing Record 44 of Set 2 | praya
# Processing Record 45 of Set 2 | kavieng
# Processing Record 46 of Set 2 | rocha
# Processing Record 47 of Set 2 | ugoofaaru
# Processing Record 48 of Set 2 | nemuro
# Processing Record 49 of Set 2 | salvacion
# Processing Record 1 of Set 3 | berlevag
# Processing Record 2 of Set 3 | imbituba
# Processing Record 3 of Set 3 | mayo
# Processing Record 4 of Set 3 | buraydah
# Processing Record 5 of Set 3 | sussex
# Processing Record 6 of Set 3 | mutoko
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | coffs harbour
# Processing Record 9 of Set 3 | bontang
# Processing Record 10 of Set 3 | tuatapere
# Processing Record 11 of Set 3 | havoysund
# City not found. Skipping...
# Processing Record 12 of Set 3 | cape coast
# Processing Record 13 of Set 3 | cabo san lucas
# City not found. Skipping...
# Processing Record 14 of Set 3 | kruisfontein
# Processing Record 15 of Set 3 | cockburn town
# Processing Record 16 of Set 3 | luderitz
# Processing Record 17 of Set 3 | tuktoyaktuk
# Processing Record 18 of Set 3 | pevek
# Processing Record 19 of Set 3 | kysyl-syr
# Processing Record 20 of Set 3 | comodoro rivadavia
# Processing Record 21 of Set 3 | brigantine
# Processing Record 22 of Set 3 | lannion
# Processing Record 23 of Set 3 | skibbereen
# Processing Record 24 of Set 3 | cubuk
# Processing Record 25 of Set 3 | ancud
# Processing Record 26 of Set 3 | lasa
# City not found. Skipping...
# Processing Record 27 of Set 3 | panzhihua
# City not found. Skipping...
# Processing Record 28 of Set 3 | pangody
# Processing Record 29 of Set 3 | jizan
# Processing Record 30 of Set 3 | esperance
# Processing Record 31 of Set 3 | lima duarte
# Processing Record 32 of Set 3 | provideniya
# Processing Record 33 of Set 3 | vila franca do campo
# Processing Record 34 of Set 3 | kostrzyn
# Processing Record 35 of Set 3 | makakilo city
# Processing Record 36 of Set 3 | tilichiki
# Processing Record 37 of Set 3 | gondanglegi
# Processing Record 38 of Set 3 | pisco
# Processing Record 39 of Set 3 | doha
# Processing Record 40 of Set 3 | vilhena
# Processing Record 41 of Set 3 | mar del plata
# Processing Record 42 of Set 3 | heihe
# Processing Record 43 of Set 3 | kodiak
# Processing Record 44 of Set 3 | dok kham tai
# Processing Record 45 of Set 3 | bayanday
# Processing Record 46 of Set 3 | katobu
# Processing Record 47 of Set 3 | la ronge
# Processing Record 48 of Set 3 | nuuk
# Processing Record 49 of Set 3 | gouyave
# Processing Record 1 of Set 4 | amapa
# Processing Record 2 of Set 4 | bethel
# City not found. Skipping...
# Processing Record 3 of Set 4 | lompoc
# Processing Record 4 of Set 4 | newport
# Processing Record 5 of Set 4 | narsaq
# Processing Record 6 of Set 4 | ajdabiya
# Processing Record 7 of Set 4 | havelock
# Processing Record 8 of Set 4 | muriwai beach
# City not found. Skipping...
# Processing Record 9 of Set 4 | sangmelima
# Processing Record 10 of Set 4 | ixtapa
# Processing Record 11 of Set 4 | klaksvik
# Processing Record 12 of Set 4 | pochutla
# Processing Record 13 of Set 4 | quelimane
# Processing Record 14 of Set 4 | mariental
# Processing Record 15 of Set 4 | yining
# Processing Record 16 of Set 4 | souillac
# Processing Record 17 of Set 4 | kankan
# Processing Record 18 of Set 4 | cabedelo
# Processing Record 19 of Set 4 | alta floresta
# Processing Record 20 of Set 4 | severo-kurilsk
# Processing Record 21 of Set 4 | touros
# Processing Record 22 of Set 4 | tezu
# Processing Record 23 of Set 4 | praia
# Processing Record 24 of Set 4 | norsup
# Processing Record 25 of Set 4 | itarema
# Processing Record 26 of Set 4 | hovd
# Processing Record 27 of Set 4 | hithadhoo
# Processing Record 28 of Set 4 | hakkari
# Processing Record 29 of Set 4 | pontes e lacerda
# Processing Record 30 of Set 4 | kharp
# Processing Record 31 of Set 4 | nantucket
# Processing Record 32 of Set 4 | caraballeda
# Processing Record 33 of Set 4 | victoria
# Processing Record 34 of Set 4 | new castle
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of Set 4 | verkhoyansk
# City not found. Skipping...
# Processing Record 36 of Set 4 | valparaiso
# City not found. Skipping...
# Processing Record 37 of Set 4 | margate
# Processing Record 38 of Set 4 | longyearbyen
# Processing Record 39 of Set 4 | nouadhibou
# Processing Record 40 of Set 4 | torbay
# Processing Record 41 of Set 4 | luebo
# Processing Record 42 of Set 4 | bartica
# Processing Record 43 of Set 4 | suez
# Processing Record 44 of Set 4 | tabuk
# City not found. Skipping...
# Processing Record 45 of Set 4 | lincoln
# City not found. Skipping...
# Processing Record 46 of Set 4 | vao
# Processing Record 47 of Set 4 | bredasdorp
# Processing Record 48 of Set 4 | tromso
# Processing Record 49 of Set 4 | lavrentiya
# Processing Record 1 of Set 5 | billings
# Processing Record 2 of Set 5 | kushima
# Processing Record 3 of Set 5 | tibati
# Processing Record 4 of Set 5 | kamenka
# Processing Record 5 of Set 5 | nyrob
# City not found. Skipping...
# Processing Record 6 of Set 5 | dakar
# Processing Record 7 of Set 5 | la asuncion
# Processing Record 8 of Set 5 | sheregesh
# Processing Record 9 of Set 5 | ponta do sol
# Processing Record 10 of Set 5 | ola
# Processing Record 11 of Set 5 | ponta delgada
# City not found. Skipping...
# Processing Record 12 of Set 5 | shakawe
# Processing Record 13 of Set 5 | pangnirtung
# Processing Record 14 of Set 5 | sasykoli
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of Set 5 | vadamadurai
# Processing Record 16 of Set 5 | gopalpur
# City not found. Skipping...
# Processing Record 17 of Set 5 | port hedland
# Processing Record 18 of Set 5 | plasencia
# Processing Record 19 of Set 5 | kontagora
# Processing Record 20 of Set 5 | alexandria
# Processing Record 21 of Set 5 | goderich
# Processing Record 22 of Set 5 | yasnyy
# Processing Record 23 of Set 5 | karratha
# Processing Record 24 of Set 5 | necochea
# Processing Record 25 of Set 5 | tazovskiy
# Processing Record 26 of Set 5 | awbari
# Processing Record 27 of Set 5 | coihaique
# Processing Record 28 of Set 5 | evensk
# Processing Record 29 of Set 5 | siguiri
# Processing Record 30 of Set 5 | boke
# Processing Record 31 of Set 5 | mahebourg
# Processing Record 32 of Set 5 | bouna
# Processing Record 33 of Set 5 | mehamn
# Processing Record 34 of Set 5 | the valley
# Processing Record 35 of Set 5 | saint-pierre
# Processing Record 36 of Set 5 | chumphon
# Processing Record 37 of Set 5 | geraldton
# Processing Record 38 of Set 5 | zhengjiatun
# Processing Record 39 of Set 5 | lebu
# Processing Record 40 of Set 5 | amatitan
# Processing Record 41 of Set 5 | jardim
# Processing Record 42 of Set 5 | butaritari
# Processing Record 43 of Set 5 | bambous virieux
# Processing Record 44 of Set 5 | artigas
# Processing Record 45 of Set 5 | gweru
# Processing Record 46 of Set 5 | halifax
# Processing Record 47 of Set 5 | teya
# Processing Record 48 of Set 5 | namatanai
# Processing Record 49 of Set 5 | maine-soroa
# Processing Record 1 of Set 6 | talnakh
# Processing Record 2 of Set 6 | kristinehamn
# Processing Record 3 of Set 6 | vernon
# Processing Record 4 of Set 6 | saldanha
# Processing Record 5 of Set 6 | sitka
# Processing Record 6 of Set 6 | tres picos
# Processing Record 7 of Set 6 | calafell
# Processing Record 8 of Set 6 | santiago del estero
# Processing Record 9 of Set 6 | nome
# Processing Record 10 of Set 6 | clyde river
# Processing Record 11 of Set 6 | faanui
# Processing Record 12 of Set 6 | morehead
# City not found. Skipping...
# Processing Record 13 of Set 6 | fairbanks
# Processing Record 14 of Set 6 | roebourne
# Processing Record 15 of Set 6 | jiazi
# Processing Record 16 of Set 6 | lakes entrance
# Processing Record 17 of Set 6 | tevriz
# Processing Record 18 of Set 6 | vardo
# Processing Record 19 of Set 6 | gandajika
# City not found. Skipping...
# Processing Record 20 of Set 6 | teguldet
# Processing Record 21 of Set 6 | qasigiannguit
# City not found. Skipping...
# Processing Record 22 of Set 6 | dingle
# Processing Record 23 of Set 6 | roma
# Processing Record 24 of Set 6 | kerema
# Processing Record 25 of Set 6 | olonets
# Processing Record 26 of Set 6 | dergachi
# Processing Record 27 of Set 6 | marawi
# Processing Record 28 of Set 6 | saskylakh
# Processing Record 29 of Set 6 | hobyo
# Processing Record 30 of Set 6 | powell river
# City not found. Skipping...
# Processing Record 31 of Set 6 | valle de allende
# Processing Record 32 of Set 6 | luxor
# Processing Record 33 of Set 6 | naze
# Processing Record 34 of Set 6 | basco
# Processing Record 35 of Set 6 | waipawa
# Processing Record 36 of Set 6 | auki
# Processing Record 37 of Set 6 | san policarpo
# Processing Record 38 of Set 6 | mao
# Processing Record 39 of Set 6 | isangel
# Processing Record 40 of Set 6 | tungor
# Processing Record 41 of Set 6 | tabou
# Processing Record 42 of Set 6 | huron
# Processing Record 43 of Set 6 | padang
# Processing Record 44 of Set 6 | los arcos
# Processing Record 45 of Set 6 | ketchikan
# Processing Record 46 of Set 6 | majene
# Processing Record 47 of Set 6 | avera
# Processing Record 48 of Set 6 | los llanos de aridane
# Processing Record 49 of Set 6 | palma
# Processing Record 1 of Set 7 | chancay
# Processing Record 2 of Set 7 | ampanihy
# Processing Record 3 of Set 7 | puerto suarez
# Processing Record 4 of Set 7 | ahipara
# Processing Record 5 of Set 7 | sao filipe
# Processing Record 6 of Set 7 | yumen
# Processing Record 7 of Set 7 | pio xii
# Processing Record 8 of Set 7 | lorengau
# Processing Record 9 of Set 7 | rauma
# Processing Record 10 of Set 7 | pipri
# Processing Record 11 of Set 7 | charlottesville
# Processing Record 12 of Set 7 | camocim
# City not found. Skipping...
# Processing Record 13 of Set 7 | boyolangu
# Processing Record 14 of Set 7 | koutsouras
# Processing Record 15 of Set 7 | muisne
# Processing Record 16 of Set 7 | palana
# Processing Record 17 of Set 7 | chattanooga
# Processing Record 18 of Set 7 | mrakovo
# Processing Record 19 of Set 7 | praia da vitoria
# Processing Record 20 of Set 7 | devonport
# Processing Record 21 of Set 7 | coahuayana
# Processing Record 22 of Set 7 | deputatskiy
# Processing Record 23 of Set 7 | sorong
# Processing Record 24 of Set 7 | edd
# City not found. Skipping...
# Processing Record 25 of Set 7 | porangatu
# Processing Record 26 of Set 7 | surgana
# Processing Record 27 of Set 7 | dyersburg
# Processing Record 28 of Set 7 | nacala
# Processing Record 29 of Set 7 | fortuna
# Processing Record 30 of Set 7 | port lincoln
# Processing Record 31 of Set 7 | pingliang
# City not found. Skipping...
# Processing Record 32 of Set 7 | rettikhovka
# Processing Record 33 of Set 7 | cruzeiro do sul
# Processing Record 34 of Set 7 | leona vicario
# Processing Record 35 of Set 7 | hofn
# Processing Record 36 of Set 7 | tigzirt
# Processing Record 37 of Set 7 | general roca
# Processing Record 38 of Set 7 | mastic beach
# Processing Record 39 of Set 7 | kidal
# Processing Record 40 of Set 7 | moose factory
# Processing Record 41 of Set 7 | bacungan
# Processing Record 42 of Set 7 | zhicheng
# Processing Record 43 of Set 7 | bosobolo
# Processing Record 44 of Set 7 | revda
# Processing Record 45 of Set 7 | banda aceh
# Processing Record 46 of Set 7 | ovsyanka
# City not found. Skipping...
# Processing Record 47 of Set 7 | grand bank
# Processing Record 48 of Set 7 | vestmannaeyjar
# Processing Record 49 of Set 7 | new milford
# Processing Record 1 of Set 8 | show low
# Processing Record 2 of Set 8 | acaponeta
# Processing Record 3 of Set 8 | maracacume
# Processing Record 4 of Set 8 | norrkoping
# Processing Record 5 of Set 8 | kudahuvadhoo
# Processing Record 6 of Set 8 | punta alta
# Processing Record 7 of Set 8 | madimba
# Processing Record 8 of Set 8 | parrita
# City not found. Skipping...
# Processing Record 9 of Set 8 | college
# Processing Record 10 of Set 8 | neuquen
# Processing Record 11 of Set 8 | yulara
# Processing Record 12 of Set 8 | swan hill
# Processing Record 13 of Set 8 | meadow lake
# Processing Record 14 of Set 8 | sur
# City not found. Skipping...
# Processing Record 15 of Set 8 | grand gaube
# Processing Record 16 of Set 8 | vila
# Processing Record 17 of Set 8 | holme
# Processing Record 18 of Set 8 | katsuura
# Processing Record 19 of Set 8 | lewiston
# Processing Record 20 of Set 8 | humaita
# Processing Record 21 of Set 8 | melfi
# Processing Record 22 of Set 8 | langres
# Processing Record 23 of Set 8 | airai
# City not found. Skipping...
# Processing Record 24 of Set 8 | cidreira
# Processing Record 25 of Set 8 | bandarbeyla
# Processing Record 26 of Set 8 | aljezur
# Processing Record 27 of Set 8 | pag
# Processing Record 28 of Set 8 | chagoda
# Processing Record 29 of Set 8 | kavaratti
# Processing Record 30 of Set 8 | tura
# Processing Record 31 of Set 8 | beyneu
# Processing Record 32 of Set 8 | challapata
# Processing Record 33 of Set 8 | chernyshevskiy
# Processing Record 34 of Set 8 | pula
# Processing Record 35 of Set 8 | sangar
# Processing Record 36 of Set 8 | fort nelson
# Processing Record 37 of Set 8 | chenzhou
# Processing Record 38 of Set 8 | crotone
# Processing Record 39 of Set 8 | flin flon
# Processing Record 40 of Set 8 | baghdad
# Processing Record 41 of Set 8 | jagannathpur
# Processing Record 42 of Set 8 | umm lajj
# Processing Record 43 of Set 8 | carauari
# Processing Record 44 of Set 8 | hokitika
# Processing Record 45 of Set 8 | tallahassee
# City not found. Skipping...
# Processing Record 46 of Set 8 | faqirwali
# Processing Record 47 of Set 8 | turukhansk
# City not found. Skipping...
# Processing Record 48 of Set 8 | ambilobe
# Processing Record 49 of Set 8 | chokurdakh
# Processing Record 1 of Set 9 | harsin
# Processing Record 2 of Set 9 | dong hoi
# Processing Record 3 of Set 9 | tecoanapa
# Processing Record 4 of Set 9 | srednekolymsk
# Processing Record 5 of Set 9 | guerrero negro
# Processing Record 6 of Set 9 | quatre cocos
# Processing Record 7 of Set 9 | alpena
# Processing Record 8 of Set 9 | belmonte
# Processing Record 9 of Set 9 | kokkola
# Processing Record 10 of Set 9 | contamana
# Processing Record 11 of Set 9 | torrington
# Processing Record 12 of Set 9 | kabo
# Processing Record 13 of Set 9 | marsa matruh
# Processing Record 14 of Set 9 | san quintin
# Processing Record 15 of Set 9 | oktyabrskiy
# Processing Record 16 of Set 9 | port shepstone
# Processing Record 17 of Set 9 | beringovskiy
# Processing Record 18 of Set 9 | emerald
# Processing Record 19 of Set 9 | constitucion
# City not found. Skipping...
# Processing Record 20 of Set 9 | moron
# Processing Record 21 of Set 9 | mbanza-ngungu
# Processing Record 22 of Set 9 | krasnorechenskiy
# Processing Record 23 of Set 9 | nsoko
# Processing Record 24 of Set 9 | lagoa
# Processing Record 25 of Set 9 | port macquarie
# Processing Record 26 of Set 9 | chipinge
# Processing Record 27 of Set 9 | chunoyar
# City not found. Skipping...
# Processing Record 28 of Set 9 | makinsk
# Processing Record 29 of Set 9 | iralaya
# Processing Record 30 of Set 9 | thompson
# Processing Record 31 of Set 9 | faya
# Processing Record 32 of Set 9 | mount gambier
# Processing Record 33 of Set 9 | isla vista
# Processing Record 34 of Set 9 | ouesso
# Processing Record 35 of Set 9 | boguchany
# Processing Record 36 of Set 9 | pitimbu
# Processing Record 37 of Set 9 | harrismith
# City not found. Skipping...
# Processing Record 38 of Set 9 | peniche
# Processing Record 39 of Set 9 | tessalit
# Processing Record 40 of Set 9 | sayat
# City not found. Skipping...
# Processing Record 41 of Set 9 | saint george
# Processing Record 42 of Set 9 | vredendal
# Processing Record 43 of Set 9 | sinnamary
# City not found. Skipping...
# Processing Record 44 of Set 9 | bijie
# Processing Record 45 of Set 9 | port blair
# Processing Record 46 of Set 9 | ballina
# Processing Record 47 of Set 9 | caceres
# Processing Record 48 of Set 9 | morgan city
# City not found. Skipping...
# Processing Record 49 of Set 9 | borovoy
# Processing Record 1 of Set 10 | zhoucheng
# Processing Record 2 of Set 10 | kirovskiy
# Processing Record 3 of Set 10 | gedo
# Processing Record 4 of Set 10 | matamoros
# Processing Record 5 of Set 10 | mananjary
# Processing Record 6 of Set 10 | hearst
# Processing Record 7 of Set 10 | sterling
# City not found. Skipping...
# Processing Record 8 of Set 10 | nelson bay
# City not found. Skipping...
# Processing Record 9 of Set 10 | bulgan
# Processing Record 10 of Set 10 | naguabo
# Processing Record 11 of Set 10 | pozhva
# Processing Record 12 of Set 10 | shahr-e kord
# Processing Record 13 of Set 10 | linxia
# Processing Record 14 of Set 10 | leningradskiy
# Processing Record 15 of Set 10 | ilulissat
# City not found. Skipping...
# Processing Record 16 of Set 10 | pombas
# Processing Record 17 of Set 10 | naco
# Processing Record 18 of Set 10 | joao pessoa
# Processing Record 19 of Set 10 | youhao
# City not found. Skipping...
# Processing Record 20 of Set 10 | talas
# Processing Record 21 of Set 10 | sorland
# Processing Record 22 of Set 10 | inuvik
# Processing Record 23 of Set 10 | grootfontein
# Processing Record 24 of Set 10 | barra
# City not found. Skipping...
# Processing Record 25 of Set 10 | azacualpa
# Processing Record 26 of Set 10 | khorinsk
# City not found. Skipping...
# Processing Record 27 of Set 10 | saint anthony
# City not found. Skipping...
# Processing Record 28 of Set 10 | namibe
# Processing Record 29 of Set 10 | saint-francois
# Processing Record 30 of Set 10 | caborca
# Processing Record 31 of Set 10 | noumea
# Processing Record 32 of Set 10 | mount isa
# Processing Record 33 of Set 10 | tonota
# Processing Record 34 of Set 10 | ostrovnoy
# Processing Record 35 of Set 10 | kaitangata
# Processing Record 36 of Set 10 | den helder
# Processing Record 37 of Set 10 | weinan
# Processing Record 38 of Set 10 | komsomolskiy
# City not found. Skipping...
# Processing Record 39 of Set 10 | tyulgan
# Processing Record 40 of Set 10 | lerwick
# Processing Record 41 of Set 10 | cabo rojo
# Processing Record 42 of Set 10 | les cayes
# Processing Record 43 of Set 10 | khoy
# Processing Record 44 of Set 10 | rochegda
# City not found. Skipping...
# Processing Record 45 of Set 10 | sao joao da barra
# Processing Record 46 of Set 10 | kandrian
# Processing Record 47 of Set 10 | mitsamiouli
# Processing Record 48 of Set 10 | mahibadhoo
# Processing Record 49 of Set 10 | svetlogorsk
# Processing Record 1 of Set 11 | sao gabriel da cachoeira
# Processing Record 2 of Set 11 | victor harbor
# Processing Record 3 of Set 11 | san juan
# City not found. Skipping...
# Processing Record 4 of Set 11 | visby
# Processing Record 5 of Set 11 | namwala
# Processing Record 6 of Set 11 | hervey bay
# Processing Record 7 of Set 11 | goksun
# Processing Record 8 of Set 11 | beaumont
# Processing Record 9 of Set 11 | hualmay
# City not found. Skipping...
# Processing Record 10 of Set 11 | georgetown
# Processing Record 11 of Set 11 | hasaki
# Processing Record 12 of Set 11 | montrose
# City not found. Skipping...
# Processing Record 13 of Set 11 | tiarei
# Processing Record 14 of Set 11 | steamboat springs
# Processing Record 15 of Set 11 | nizhniy ingash
# Processing Record 16 of Set 11 | poum
# City not found. Skipping...
# Processing Record 17 of Set 11 | beckley
# Processing Record 18 of Set 11 | nuevo progreso
# Processing Record 19 of Set 11 | sobolevo
# Processing Record 20 of Set 11 | gizo
# Processing Record 21 of Set 11 | maniitsoq
# City not found. Skipping...
# Processing Record 22 of Set 11 | slave lake
# Processing Record 23 of Set 11 | sibolga
# Processing Record 24 of Set 11 | kaoma
# Processing Record 25 of Set 11 | abu dhabi
# Processing Record 26 of Set 11 | beziers
# Processing Record 27 of Set 11 | marathon
# Processing Record 28 of Set 11 | mocuba
# Processing Record 29 of Set 11 | minab
# Processing Record 30 of Set 11 | baoning
# Processing Record 31 of Set 11 | tautira
# Processing Record 32 of Set 11 | havre-saint-pierre
# Processing Record 33 of Set 11 | aswan
# Processing Record 34 of Set 11 | menongue
# Processing Record 35 of Set 11 | solnechnyy
# Processing Record 36 of Set 11 | manzil kamil
# Processing Record 37 of Set 11 | sirohi
# Processing Record 38 of Set 11 | vestmanna
# Processing Record 39 of Set 11 | tashara
# Processing Record 40 of Set 11 | xichang
# Processing Record 41 of Set 11 | rawson
# Processing Record 42 of Set 11 | ercis
# Processing Record 43 of Set 11 | bougouni
# Processing Record 44 of Set 11 | poltavka
# Processing Record 45 of Set 11 | baykit
# Processing Record 46 of Set 11 | wad rawah
# City not found. Skipping...
# Processing Record 47 of Set 11 | kabin buri
# City not found. Skipping...
# Processing Record 48 of Set 11 | honningsvag
# Processing Record 49 of Set 11 | nyurba
# Processing Record 1 of Set 12 | gat
# Processing Record 2 of Set 12 | jacqueville
# Processing Record 3 of Set 12 | fare
# Processing Record 4 of Set 12 | rockland
# Processing Record 5 of Set 12 | ulladulla
# Processing Record 6 of Set 12 | deer lake
# Processing Record 7 of Set 12 | piacabucu
# City not found. Skipping...
# Processing Record 8 of Set 12 | arica
# Processing Record 9 of Set 12 | winslow
# Processing Record 10 of Set 12 | witney
# Processing Record 11 of Set 12 | atar
# Processing Record 12 of Set 12 | zhaoyang
# Processing Record 13 of Set 12 | shenyang
# Processing Record 14 of Set 12 | shahrud
# Processing Record 15 of Set 12 | watsa
# Processing Record 16 of Set 12 | darhan
# Processing Record 17 of Set 12 | manadhoo
# Processing Record 18 of Set 12 | trairi
# City not found. Skipping...
# Processing Record 19 of Set 12 | truckee
# Processing Record 20 of Set 12 | igarka
# Processing Record 21 of Set 12 | henties bay
# Processing Record 22 of Set 12 | kupang
# Processing Record 23 of Set 12 | plouzane
# Processing Record 24 of Set 12 | san francisco
# Processing Record 25 of Set 12 | waddan
# Processing Record 26 of Set 12 | clearwater
# Processing Record 27 of Set 12 | pimentel
# Processing Record 28 of Set 12 | christchurch
# City not found. Skipping...
# Processing Record 29 of Set 12 | rotterdam
# Processing Record 30 of Set 12 | burnie
# Processing Record 31 of Set 12 | seoul
# Processing Record 32 of Set 12 | nova venecia
# Processing Record 33 of Set 12 | brae
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create dictionary for all the variables that extract from openweather
cities_dict={"City":city_list,
             "Cloudiness":clouds,
             "Country":country,
             "Date":date,
             "Humidity":humidity,
             "Latitude":latitude,
             "Longitude":longitude,
             "Max Temp":max_temp,
             "Wind Speed":wind_speed}

# %%
#convert dictionary to dataframe
cities_df=pd.DataFrame(cities_dict)
cities_df.count()
# Out:
# City          572
# Cloudiness    572
# Country       572
# Date          572
# Humidity      572
# Latitude      572
# Longitude     572
# Max Temp      572
# Wind Speed    572
# dtype: int64

# %%
cities_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity  Latitude  \
# 0         te anau          96      NZ  1574189900        91    -45.41
# 1          pangoa         100      PE  1574189900        39    -12.12
# 2            galt          90      CA  1574189644       100     43.36
# 3          anadyr          40      RU  1574189901        84     64.73
# 4  ribeira grande          40      PT  1574189901        63     38.52
#
#    Longitude  Max Temp  Wind Speed
# 0     167.72     39.51        6.87
# 1     -73.00     92.07        4.52
# 2     -80.31     42.01        3.36
# 3     177.51      5.00        4.47
# 4     -28.70     64.40       16.11

# %%
# output data to csv
cities_df.to_csv("city_weather.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(cities_df["Latitude"],cities_df["Max Temp"],edgecolors="black",facecolors="steelblue")
plt.title("City Latitude vs. Max Temperature (11/19/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Png/Lat vs Max Temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cities_df["Latitude"],cities_df["Humidity"],edgecolors="black",facecolors="steelblue")
plt.title("City Latitude vs. Humidity (11/19/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Png/Lat vs Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities_df["Latitude"],cities_df["Cloudiness"],edgecolors="black",facecolors="steelblue")
plt.title("City Latitude vs. Cloudiness (11/19/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Png/Lat vs Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_df["Latitude"],cities_df["Wind Speed"],edgecolors="black",facecolors="steelblue")
plt.title("City Latitude vs. Wind Speed (11/19/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Png/Lat vs Wind Speed.png")
